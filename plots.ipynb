# %% [markdown]
# # Imports

# %%
import seaborn as sns
import numpy as np

# %%
sns.set_style("whitegrid")

# %%
# MSE Plot

b = np.linspace(-7, 3, 300)
y = (1 - (2 + 1 + b)) ** 2

sns.scatterplot(x = b,y = y, label = "Cost Function")

#MSE partial derivative(pd) plot
pd_b = np.linspace(-7, 3, 300)
pd_y = -2 * (1 - (2 + 1 + pd_b)) 

sns.scatterplot(x = pd_b,y = pd_y, label = "PD of Cost Function")
plt.title("Graph of Cost Function MSE") 
plt.show()
